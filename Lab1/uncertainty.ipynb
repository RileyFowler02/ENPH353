# %%
import numpy as np
import qexpy as q
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
times = [1.59, 1.48, 1.55, 1.59, 1.61, 1.53, 1.46, 1.60, 1.53, 1.61, 1.58, 1.46, 1.54, 1.57, 1.59, 1.53, 1.56, 1.59, 1.55, 1.50, 1.53, 1.54, 1.66, 1.68, 1.55, 1.56, 1.5, 1.54, 1.59, 1.61, 1.53, 1.56, 1.61, 1.55, 1.53, 1.59, 1.42, 1.59]
print("Mean: ", np.mean(times))
# Out:
# Mean:  1.5568421052631582

# %%
import matplotlib.pyplot as plt

q7_data = [
    {'angle': 10, 'period': 1.513},
    {'angle': 20, 'period': 1.54},
    {'angle': 30, 'period': 1.56},
    {'angle': 40, 'period': 1.58},
    {'angle': 50, 'period': 1.62},
    {'angle': 60, 'period': 1.64},
    {'angle': 70, 'period': 1.64},
]

plt.plot([d['angle'] for d in q7_data], [d['period'] for d in q7_data])
plt.show()
