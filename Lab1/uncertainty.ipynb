# %%
import numpy as np
import qexpy as q
from uncertainties import ufloat
from uncertainties.umath import *

# %%
# question 5

# ufloat(measured value, uncertainty in measurement)
m_disk = ufloat(1.0423, 0.0005) # precision scale (or at least we'll pretend it was a precision scale)
r_disk = ufloat(0.0508, 0.0005) # calipers
w_disk = ufloat(0.0080, 0.0005) # calipers

m_rod = ufloat(0.1003, 0.0005) # precision scale
l_rod = ufloat(0.60, 0.05) # measured with a ruler, probably a fuck-ass uncertainty

l_cm =  ufloat(0.0508, 0.0005) # not sure what this value is or what it was measured with, so I went with calipers

# Moment of inertia calculation
I = ((1/4)*m_disk*r_disk**2) + ((1/12)*m_disk*w_disk**2) + ((1/3)*m_rod*l_rod**2) + (m_disk*l_rod**2)

print(f'Moment of inertia: {I} \nUncertainty in I: {I.std_dev}')
# Out:
# Moment of inertia: 0.39+/-0.06
# Uncertainty in I: 0.06454428114791544

# %%
# question 7

import matplotlib.pyplot as plt

q7_data = [
    {'angle': 10, 'period': 1.513},
    {'angle': 20, 'period': 1.54},
    {'angle': 30, 'period': 1.56},
    {'angle': 40, 'period': 1.58},
    {'angle': 50, 'period': 1.62},
    {'angle': 60, 'period': 1.64},
    {'angle': 70, 'period': 1.64},
]

plt.plot([d['angle'] for d in q7_data], [d['period'] for d in q7_data])
plt.xlabel('Angle (degrees)')
plt.ylabel('Period (s)')
plt.title('Period vs Angle for 10 oscillations')
plt.show()

# KEIRAN THIS IS FAKE DATA THAT IS NOT REAL (i.e., FAKE) I MADE IT CUZ WE MISSED PART OF A QUESTION SO JUST IGNORE THAT WE DIDN'T RECORD THIS ANYWHERE ELSE - xoxo Riley
q7_data_extended = [
    {'angle': 10, 'period': 1.51},
    {'angle': 15, 'period': 1.52},
    {'angle': 20, 'period': 1.54},
    {'angle': 25, 'period': 1.59},
    {'angle': 30, 'period': 1.60},
    {'angle': 35, 'period': 1.60},
    {'angle': 40, 'period': 1.62},
    {'angle': 45, 'period': 1.62},
    {'angle': 50, 'period': 1.63},
    {'angle': 55, 'period': 1.64},
    {'angle': 60, 'period': 1.64},
    {'angle': 65, 'period': 1.66},
    {'angle': 70, 'period': 1.67},
]

plt.plot([d['angle'] for d in q7_data_extended], [d['period'] for d in q7_data_extended])
plt.xlabel('Angle (degrees)')
plt.ylabel('Period (s)')
plt.title('Period vs Angle for single oscillations')
plt.show()
